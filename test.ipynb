# %%
from dotenv import load_dotenv
from langchain_tavily import TavilySearch

_ = load_dotenv()


def get_tavily(include_answer=True, k=5):
    return TavilySearch(include_answer=include_answer, k=k)

# %%
from urllib.parse import quote_plus

# Replace these with your actual values
username = "myuser"
password = "my:password"  # Password with a colon
host = "localhost"
port = "5433"
db_name = "mydatabase"

safe_password = quote_plus(password)
database_url = f"postgresql+asyncpg://{username}:{safe_password}@{host}:{port}/{db_name}"

print(database_url)
# Out:
# postgresql+asyncpg://myuser:my%3Apassword@localhost:5433/mydatabase

# %%
from app.core.config.settings import settings

print(settings.database_url)
# Out:
# postgresql+asyncpg://careerpilot:password@localhost:5433/careerpilot

# %%
import re

jina_prefix = "https://r.jina.ai/"
original_url = "https://jobs.ashbyhq.com/clera/f50523b4-3533-4b97-885c-f412d4611411"

# The '^' anchor ensures we only replace 'https://' if it is at the very start
jina_url = re.sub(r"^https://", jina_prefix, original_url)

print(jina_url)
# Output: https://r.jina.ai/example.com/some/path
# Out:
# https://r.jina.ai/jobs.ashbyhq.com/clera/f50523b4-3533-4b97-885c-f412d4611411

# %%
await populate_job_descriptions()
# Out:
# Rate limited by Jina: https://nreach.keka.com/careers/jobdetails/134039
# Rate limited by Jina: https://absa.wd3.myworkdayjobs.com/en-US/ABSAcareersite/job/Product-Engineer---Data-Quality_R-15988995
# Rate limited by Jina: https://workday.wd5.myworkdayjobs.com/en-US/Workday/job/Analytics-Sr-Software-Engineer--US-Federal-_JR-0105496
# Rate limited by Jina: https://tarento.keka.com/careers/jobdetails/77554
# Rate limited by Jina: https://nelnet.wd1.myworkdayjobs.com/en-US/MyNelnet/job/Senior-Product-Manager--Payment-Systems-and-Fraud-Prevention_R22786
# Rate limited by Jina: https://nelnet.wd1.myworkdayjobs.com/en-US/MyNelnet/job/Senior-Product-Manager--Payment-Systems-and-Fraud-Prevention_R22786
# Rate limited by Jina: https://hitachi.wd1.myworkdayjobs.com/en-US/hitachi/job/Software-Engineer-for-HVDC-Control-and-Protection-Software_R0131066
# Rate limited by Jina: https://melcoresorts.wd3.myworkdayjobs.com/en-US/career/job/Senior-Manager--Software-Engineering_REQ14503
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
